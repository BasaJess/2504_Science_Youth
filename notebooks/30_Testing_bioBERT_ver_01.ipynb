# %% [markdown]
# #### Model deployment and use
# ---

# %% [markdown]
# we already pre-trained a bioBERT model for classification, summarization and relevance of scientific papers related to healthspan and lifespan. It is saved in a local directory. Here we  implement its deployment, and use it to scan a directory, and display a summary and information of each of the 15 most recent documents relevant to the topic. Also a summary of these documents

# %% [markdown]
# 1. Load the pre-trained BioBERT model and tokenizer

# %%
import json
import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer, pipeline, AutoModelForSeq2SeqLM

# %%
model_dir = "../models/biobert_healthspan"
#model_name = "michiyasunaga/BioBART-large"

# %%
model = AutoModelForSequenceClassification.from_pretrained(model_dir)

# %%
tokenizer = AutoTokenizer.from_pretrained(model_dir)

# %% [markdown]
# 2. Setup PDF text extraction

# %%
#import fitz  # PyMuPDF

#def extract_text_from_pdf(pdf_path):
#    doc = fitz.open(pdf_path)
#    text = ""
#    for page_num in range(doc.page_count):
#        page = doc.load_page(page_num)
#        text += page.get_text()
#    return text

# %% [markdown]
# 3. Or work from the json file

# %% [markdown]
# - Load the json file
#
# We’ll start by loading the JSON file and extracting the relevant fields (title, author, date, processed_text, and filename)

# %% [markdown]
#  - Preprocess the documents
#
# We’ll then process the processed_text for relevance classification and summarization, ignoring the label.

# %% [markdown]
#  - Display summaries of the top 15 relevant documents

# %%
# PDF extraction function (no longer necessary as we are using processed_text)
# Extract data from JSON file
json_file_path = "../data/preprocessed_pdf_info_list.json"  # Replace with the path to your JSON file

with open(json_file_path, 'r') as file:
    pdf_data = json.load(file)

# %%
# Classify relevance of documents
def classify_document(text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
    predictions = torch.argmax(outputs.logits, dim=-1)
    return predictions.item()

# %%
# Summarization function
summarizer = pipeline("summarization", model="facebook/bart-large-cnn")

def summarize_document(text):
    summary = summarizer(text, max_length=200, min_length=50, do_sample=False)
    return summary[0]['summary_text']
# Out:
# Device set to use cpu

# %%
# Process and classify the documents
relevant_documents = []

# %%
# Ensure pdf_data is a list
if not isinstance(pdf_data, list):
    raise ValueError("Expected 'pdf_data' to be a list of dictionaries.")

# %%
for idx, document in enumerate(pdf_data):
    try:
        # Ensure document is a dictionary
        if not isinstance(document, dict):
            print(f"Warning: Document at index {idx} is not a dictionary. Skipping...")
            continue

        # Retrieve processed text
        processed_text = document.get("processed_text", "")

        # Ensure processed_text is a valid string
        if not isinstance(processed_text, str) or not processed_text.strip():
            print(f"Warning: Document '{document.get('filename', 'Unknown')}' has no valid processed text. Skipping...")
            continue

        # Classify document
        relevance = classify_document(processed_text)

        # Ensure classification output is valid
        if not isinstance(relevance, int):
            print(f"Error: Classification output for '{document.get('filename', 'Unknown')}' is not an integer. Skipping...")
            continue

        # Check if document is relevant
        if relevance == 1:  # Assuming '1' means relevant
            relevant_documents.append(document)

    except Exception as e:
        print(f"Error processing document at index {idx}: {e}")
# Out:
# Error processing document at index 473: TextEncodeInput must be Union[TextInputSequence, Tuple[InputSequence, InputSequence]]

# %%
print(f"Total relevant documents found: {len(relevant_documents)}")
# Out:
# Total relevant documents found: 653

# %%
from datetime import datetime

# %%
def get_sortable_date(doc):
    """
    Extracts and converts the date to a sortable format.
    If the date is missing, invalid, or doc is None, returns a default old date.
    """
    try:
        if not isinstance(doc, dict):  # Ensure doc is a valid dictionary
            print(f"Warning: Encountered an invalid document entry: {doc}. Skipping.")
            return datetime(1900, 1, 1)

        date_str = doc.get("date", "")

        if not isinstance(date_str, str) or not date_str.strip():
            print(f"Warning: Missing or invalid date in document '{doc.get('filename', 'Unknown')}'. Using default old date.")
            return datetime(1900, 1, 1)

        return datetime.strptime(date_str.strip(), "%Y-%m-%d")  # Adjust format if needed

    except Exception as e:
        print(f"Error processing date for document '{doc.get('filename', 'Unknown')}': {e}")
        return datetime(1900, 1, 1)  # Return default old date to avoid breaking the sort

# %%
# Sort documents safely
try:
    relevant_documents = [doc for doc in relevant_documents if isinstance(doc, dict)]  # Remove None or invalid entries
    relevant_documents.sort(key=get_sortable_date, reverse=True)
except Exception as e:
    print(f"Error while sorting documents: {e}")
    raise  # Re-raise for debugging if needed
# Out:
# Error processing date for document '0706.1996.pdf': unconverted data remains: T23:21:48
# Error processing date for document '1102.0933.pdf': unconverted data remains: T13:41:06
# Error processing date for document '1102.3369.pdf': unconverted data remains: T11:49:30
# Error processing date for document '1109.1296.pdf': unconverted data remains: T02:25:30
# Warning: Missing or invalid date in document '1201.2900.pdf'. Using default old date.
# Error processing date for document '1207.1891.pdf': unconverted data remains: T22:37:20
# Error processing date for document '1209.5046.pdf': unconverted data remains: T07:18:13
# Error processing date for document '1209.5754.pdf': unconverted data remains: T11:42:42
# Error processing date for document '1210.0037.pdf': unconverted data remains: T16:35:17
# Error processing date for document '1210.7480.pdf': unconverted data remains: T01:01:44
# Error processing date for document '1211.4911.pdf': unconverted data remains: T22:18:10
# Error processing date for document '1301.1077.pdf': unconverted data remains: T01:36:25
# Error processing date for document '1302.3861.pdf': unconverted data remains: T06:59:03
# Error processing date for document '1304.0479.pdf': unconverted data remains: T20:21:45
# Error processing date for document '1304.3546.pdf': unconverted data remains: T08:36:57
# Error processing date for document '1305.0113.pdf': unconverted data remains: T10:18:02
# Error processing date for document '1305.3634.pdf': unconverted data remains: T20:36:25
# Error processing date for document '1306.5104.pdf': unconverted data remains: T16:30:29
# Error processing date for document '1307.6583.pdf': unconverted data remains: T23:28:27
# Error processing date for document '1308.3690.pdf': unconverted data remains: T11:40:13
# Error processing date for document '1311.4276.pdf': unconverted data remains: T05:45:19
# Error processing date for document '1311.4706.pdf': unconverted data remains: T07:16:50
# Error processing date for document '1312.6356.pdf': unconverted data remains: T20:59:50
# Error processing date for document '1401.2413.pdf': unconverted data remains: T17:38:22
# Warning: Missing or invalid date in document '1401.5901.pdf'. Using default old date.
# Error processing date for document '1401.7497.pdf': unconverted data remains: T18:12:45
# Error processing date for document '1402.0836.pdf': unconverted data remains: T19:04:42
# Error processing date for document '1402.2272.pdf': unconverted data remains: T13:29:23
# Error processing date for document '1402.6367.pdf': unconverted data remains: T22:37:52
# Error processing date for document '1402.6465.pdf': unconverted data remains: T11:35:32
# Error processing date for document '1402.6910.pdf': unconverted data remains: T13:43:27
# Error processing date for document '1403.0638.pdf': unconverted data remains: T17:50:28
# Error processing date for document '1403.1876.pdf': unconverted data remains: T23:12:35
# Error processing date for document '1404.3604.pdf': unconverted data remains: T16:16:15
# Error processing date for document '1404.4804.pdf': unconverted data remains: T05:52:54
# Error processing date for document '1404.5111.pdf': unconverted data remains: T21:43:35
# Error processing date for document '1406.1976.pdf': unconverted data remains: T17:19:14
# Error processing date for document '1406.6612.pdf': unconverted data remains: T16:08:40
# Error processing date for document '1407.6030.pdf': unconverted data remains: T02:10:00
# Error processing date for document '1407.7622.pdf': unconverted data remains: T01:14:50
# Error processing date for document '1408.0463.pdf': unconverted data remains: T09:17:46
# Error processing date for document '1408.1325.pdf': unconverted data remains: T12:15:19
# Warning: Missing or invalid date in document '1408.4856.pdf'. Using default old date.
# Error processing date for document '1409.1542.pdf': unconverted data remains: T10:16:38
# Error processing date for document '1409.5062.pdf': unconverted data remains: T13:21:28
# Error processing date for document '1409.7827.pdf': unconverted data remains: T14:24:47
# Error processing date for document '1412.5062.pdf': unconverted data remains: T14:49:13
# Error processing date for document '1502.00759.pdf': unconverted data remains: T20:28:32
# Error processing date for document '1502.04307.pdf': unconverted data remains: T00:34:02
# Error processing date for document '1503.06159.pdf': unconverted data remains: T19:54:16
# Error processing date for document '1503.07040.pdf': unconverted data remains: T14:10:16
# Error processing date for document '1503.07518.pdf': unconverted data remains: T20:58:56
# Error processing date for document '1504.03576.pdf': unconverted data remains: T18:41:11
# Error processing date for document '1504.03984.pdf': unconverted data remains: T10:42:32
# Error processing date for document '1505.02474.pdf': unconverted data remains: T16:07:46
# Error processing date for document '1505.03900.pdf': unconverted data remains: T10:28:04
# Error processing date for document '1505.03902.pdf': unconverted data remains: T09:58:50
# Error processing date for document '1505.05121.pdf': unconverted data remains: T19:41:07
# Error processing date for document '1506.03893.pdf': unconverted data remains: T14:19:16
# Error processing date for document '1506.06795.pdf': unconverted data remains: T12:59:37
# Error processing date for document '1508.02200.pdf': unconverted data remains: T16:29:04
# Error processing date for document '1510.00767.pdf': unconverted data remains: T17:03:32
# Error processing date for document '1510.05296.pdf': unconverted data remains: T06:16:28
# Error processing date for document '1510.08045.pdf': unconverted data remains: T13:33:10
# Error processing date for document '1511.01239.pdf': unconverted data remains: T09:15:52
# Error processing date for document '1511.04470.pdf': unconverted data remains: T16:58:00
# Error processing date for document '1512.05213.pdf': unconverted data remains: T17:37:03
# Error processing date for document '1512.05431.pdf': unconverted data remains: T05:42:47
# Error processing date for document '1512.07644.pdf': unconverted data remains: T20:06:13
# Error processing date for document '1601.03419.pdf': unconverted data remains: T01:36:03
# Error processing date for document '1602.00600.pdf': unconverted data remains: T16:15:22
# Error processing date for document '1602.00723.pdf': unconverted data remains: T18:19:13
# Error processing date for document '1602.02569.pdf': unconverted data remains: T00:52:35
# Error processing date for document '1603.04007.pdf': unconverted data remains: T03:30:54
# Error processing date for document '1603.06941.pdf': unconverted data remains: T17:30:10
# Error processing date for document '1603.09076.pdf': unconverted data remains: T02:05:31
# Error processing date for document '1604.00976.pdf': unconverted data remains: T00:29:04
# Error processing date for document '1604.06358.pdf': unconverted data remains: T08:26:04
# Error processing date for document '1605.07488.pdf': unconverted data remains: T09:49:13
# Error processing date for document '1606.01788.pdf': unconverted data remains: T17:35:31
# Error processing date for document '1606.03910.pdf': unconverted data remains: T15:27:34
# Error processing date for document '1606.04519.pdf': unconverted data remains: T02:37:12
# Error processing date for document '1606.09545.pdf': unconverted data remains: T12:37:22
# Error processing date for document '1607.01449.pdf': unconverted data remains: T12:11:21
# Error processing date for document '1607.07259.pdf': unconverted data remains: T17:23:08
# Error processing date for document '1607.07834.pdf': unconverted data remains: T18:22:00
# Error processing date for document '1608.04824.pdf': unconverted data remains: T00:22:04
# Error processing date for document '1609.01570.pdf': unconverted data remains: T14:19:33
# Error processing date for document '1609.07214.pdf': unconverted data remains: T03:00:29
# Error processing date for document '1610.03668.pdf': unconverted data remains: T10:51:53
# Error processing date for document '1610.07278.pdf': unconverted data remains: T08:02:37
# Error processing date for document '1611.03191.pdf': unconverted data remains: T18:23:14
# Warning: Missing or invalid date in document '1611.06049.pdf'. Using default old date.
# Error processing date for document '1612.00396.pdf': unconverted data remains: T21:20:27
# Error processing date for document '1612.01429.pdf': unconverted data remains: T03:31:03
# Error processing date for document '1612.03859.pdf': unconverted data remains: T15:59:47
# Error processing date for document '1612.03976.pdf': unconverted data remains: T22:46:40
# Error processing date for document '1612.06650.pdf': unconverted data remains: T20:42:07
# Error processing date for document '1705.03318.pdf': unconverted data remains: T00:27:05
# Error processing date for document '1705.08396.pdf': unconverted data remains: T03:04:56
# Error processing date for document '1706.03085.pdf': unconverted data remains: T10:26:22
# Error processing date for document '1706.09813.pdf': unconverted data remains: T08:19:18
# Error processing date for document '1708.02967.pdf': unconverted data remains: T11:37:01
# Error processing date for document '1709.07439.pdf': unconverted data remains: T08:20:01
# Error processing date for document '1709.09850.pdf': unconverted data remains: T12:06:32
# Error processing date for document '1710.00960.pdf': unconverted data remains: T18:40:08
# Error processing date for document '1710.02362.pdf': unconverted data remains: T14:04:43
# Error processing date for document '1710.03268.pdf': unconverted data remains: T18:55:05
# Error processing date for document '1710.04195.pdf': unconverted data remains: T18:00:56
# Error processing date for document '1710.05246.pdf': unconverted data remains: T20:34:24
# Error processing date for document '1712.01481.pdf': unconverted data remains: T05:21:50
# Error processing date for document '1712.04377.pdf': unconverted data remains: T12:15:34
# Error processing date for document '1712.04680.pdf': unconverted data remains: T10:53:59
# Error processing date for document '1712.06042.pdf': unconverted data remains: T23:03:25
# Error processing date for document '1801.02645.pdf': unconverted data remains: T02:10:27
# Error processing date for document '1801.07113.pdf': unconverted data remains: T15:52:44
# Error processing date for document '1801.08073.pdf': unconverted data remains: T10:36:05
# Error processing date for document '1801.09257.pdf': unconverted data remains: T02:58:30
# Error processing date for document '1801.09528.pdf': unconverted data remains: T11:28:22
# Error processing date for document '1801.10195.pdf': unconverted data remains: T01:53:56
# Error processing date for document '1802.02378.pdf': unconverted data remains: T19:28:18
# Error processing date for document '1802.02516.pdf': unconverted data remains: T21:57:23
# Error processing date for document '1802.02937.pdf': unconverted data remains: T19:30:26
# Error processing date for document '1802.07488.pdf': unconverted data remains: T01:24:31
# Error processing date for document '1802.07569.pdf': unconverted data remains: T02:03:43
# Error processing date for document '1803.03475.pdf': unconverted data remains: T01:31:38
# Error processing date for document '1803.03571.pdf': unconverted data remains: T01:36:33
# Error processing date for document '1803.04024.pdf': unconverted data remains: T00:24:27
# Error processing date for document '1803.04915.pdf': unconverted data remains: T11:28:48
# Error processing date for document '1803.10063.pdf': unconverted data remains: T09:27:33
# Error processing date for document '1804.01069.pdf': unconverted data remains: T00:25:38
# Error processing date for document '1805.01530.pdf': unconverted data remains: T13:10:22
# Error processing date for document '1805.01552.pdf': unconverted data remains: T23:01:30
# Error processing date for document '1805.06681.pdf': unconverted data remains: T12:51:11
# Error processing date for document '1805.07058.pdf': unconverted data remains: T00:54:35
# Error processing date for document '1806.01467.pdf': unconverted data remains: T15:11:22
# Error processing date for document '1806.06716.pdf': unconverted data remains: T03:25:32
# Error processing date for document '1806.11376.pdf': unconverted data remains: T00:48:40
# Error processing date for document '1807.02288.pdf': unconverted data remains: T08:53:20
# Error processing date for document '1807.05637.pdf': unconverted data remains: T20:18:51
# Error processing date for document '1809.01241.pdf': unconverted data remains: T14:56:48
# Error processing date for document '1809.03732.pdf': unconverted data remains: T09:23:35
# Error processing date for document '1809.05880.pdf': unconverted data remains: T10:39:16
# Error processing date for document '1810.10664.pdf': unconverted data remains: T00:24:38
# Error processing date for document '1810.11195.pdf': unconverted data remains: T17:28:18
# Error processing date for document '1811.00649.pdf': unconverted data remains: T14:21:47
# Error processing date for document '1811.03943.pdf': unconverted data remains: T17:29:02
# Error processing date for document '1811.03952.pdf': unconverted data remains: T01:22:24
# Error processing date for document '1811.06018.pdf': unconverted data remains: T14:04:36
# Error processing date for document '1811.07093.pdf': unconverted data remains: T20:49:42
# Error processing date for document '1811.09326.pdf': unconverted data remains: T01:41:07
# Error processing date for document '1812.07839.pdf': unconverted data remains: T15:24:05
# Error processing date for document '1901.00099.pdf': unconverted data remains: T19:33:31
# Error processing date for document '1901.04053.pdf': unconverted data remains: T20:33:44
# Error processing date for document '1901.06932.pdf': unconverted data remains: T02:35:53
# Error processing date for document '1901.07963.pdf': unconverted data remains: T02:11:22
# Error processing date for document '1903.04987.pdf': unconverted data remains: T15:14:46
# Error processing date for document '1903.05144.pdf': unconverted data remains: T13:01:33
# Error processing date for document '1903.05449.pdf': unconverted data remains: T12:29:42
# Error processing date for document '1903.12138.pdf': unconverted data remains: T17:43:03
# Error processing date for document '1904.01235.pdf': unconverted data remains: T00:41:55
# Error processing date for document '1904.02243.pdf': unconverted data remains: T00:40:54
# Error processing date for document '1904.03024.pdf': unconverted data remains: T21:54:01
# Error processing date for document '1904.05026.pdf': unconverted data remains: T06:51:22
# Error processing date for document '1904.05036.pdf': unconverted data remains: T09:23:58
# Error processing date for document '1904.05043.pdf': unconverted data remains: T09:58:02
# Error processing date for document '1904.12652.pdf': unconverted data remains: T08:40:24
# Error processing date for document '1905.02621.pdf': unconverted data remains: T21:54:45
# Error processing date for document '1905.03004.pdf': unconverted data remains: T23:05:17
# Error processing date for document '1905.07774.pdf': unconverted data remains: T00:55:20
# Error processing date for document '1905.08099.pdf': unconverted data remains: T23:54:11
# Error processing date for document '1905.08912.pdf': unconverted data remains: T01:02:01
# Error processing date for document '1905.12405.pdf': unconverted data remains: T20:36:01
# Error processing date for document '1906.00862.pdf': unconverted data remains: T17:17:44
# Error processing date for document '1906.00871.pdf': unconverted data remains: T22:07:02
# Error processing date for document '1906.05820.pdf': unconverted data remains: T12:05:25
# Error processing date for document '1906.08154.pdf': unconverted data remains: T02:16:05
# Error processing date for document '1906.12047.pdf': unconverted data remains: T01:13:34
# Error processing date for document '1906.12048.pdf': unconverted data remains: T15:22:49
# Error processing date for document '1907.00329.pdf': unconverted data remains: T01:33:28
# Error processing date for document '1907.01666.pdf': unconverted data remains: T00:51:42
# Error processing date for document '1907.08711.pdf': unconverted data remains: T00:48:58
# Error processing date for document '1907.12742.pdf': unconverted data remains: T07:09:30
# Error processing date for document '1908.01555.pdf': unconverted data remains: T00:51:44
# Error processing date for document '1908.05298.pdf': unconverted data remains: T14:53:28
# Error processing date for document '1908.07048.pdf': unconverted data remains: T00:22:22
# Error processing date for document '1908.07611.pdf': unconverted data remains: T11:14:58
# Error processing date for document '1908.08135.pdf': unconverted data remains: T02:26:53
# Error processing date for document '1909.01735.pdf': unconverted data remains: T00:39:52
# Error processing date for document '1909.02199.pdf': unconverted data remains: T01:01:40
# Error processing date for document '1909.04560.pdf': unconverted data remains: T01:11:37
# Error processing date for document '1909.05198.pdf': unconverted data remains: T06:00:09
# Error processing date for document '1909.07469.pdf': unconverted data remains: T22:39:24
# Error processing date for document '1909.10580.pdf': unconverted data remains: T14:11:50
# Error processing date for document '1909.10733.pdf': unconverted data remains: T00:48:23
# Error processing date for document '1909.10903.pdf': unconverted data remains: T03:47:22
# Error processing date for document '1909.11447.pdf': unconverted data remains: T05:00:56
# Error processing date for document '1909.11956.pdf': unconverted data remains: T21:51:36
# Error processing date for document '1910.01297.pdf': unconverted data remains: T00:50:05
# Error processing date for document '1910.02815.pdf': unconverted data remains: T17:46:04
# Error processing date for document '1910.06899.pdf': unconverted data remains: T01:00:54
# Error processing date for document '1910.10968.pdf': unconverted data remains: T00:57:27
# Error processing date for document '1910.11180.pdf': unconverted data remains: T18:40:43
# Error processing date for document '1910.12055.pdf': unconverted data remains: T10:16:10
# Error processing date for document '1911.00863.pdf': unconverted data remains: T10:52:59
# Error processing date for document '1911.01174.pdf': unconverted data remains: T03:21:09
# Error processing date for document '1911.09035.pdf': unconverted data remains: T01:44:43
# Error processing date for document '1911.10617.pdf': unconverted data remains: T01:09:33
# Error processing date for document '1912.02899.pdf': unconverted data remains: T21:45:39
# Error processing date for document '1912.02901.pdf': unconverted data remains: T15:38:34
# Error processing date for document '1912.08163.pdf': unconverted data remains: T22:04:03
# Error processing date for document '1912.13167.pdf': unconverted data remains: T22:24:59
# Error processing date for document '2001.00209.pdf': unconverted data remains: T17:12:17
# Error processing date for document '2001.03426.pdf': unconverted data remains: T15:18:03
# Error processing date for document '2001.03561.pdf': unconverted data remains: T18:31:22
# Error processing date for document '2001.06979.pdf': unconverted data remains: T05:08:58
# Warning: Missing or invalid date in document '2002.04136.pdf'. Using default old date.
# Error processing date for document '2002.06401.pdf': unconverted data remains: T21:51:00
# Error processing date for document '2002.08294.pdf': unconverted data remains: T14:48:29
# Error processing date for document '2002.10430.pdf': unconverted data remains: T18:18:31
# Error processing date for document '2002.12316.pdf': unconverted data remains: T21:02:41
# Error processing date for document '2003.01042.pdf': unconverted data remains: T01:51:48
# Error processing date for document '2003.01053.pdf': unconverted data remains: T11:34:33
# Error processing date for document '2003.02510.pdf': unconverted data remains: T23:01:23
# Error processing date for document '2003.05350.pdf': unconverted data remains: T20:28:26
# Error processing date for document '2003.05776.pdf': unconverted data remains: T18:16:03
# Error processing date for document '2003.07105.pdf': unconverted data remains: T01:12:02
# Error processing date for document '2003.07494.pdf': unconverted data remains: T02:05:03
# Error processing date for document '2003.08518.pdf': unconverted data remains: T11:15:38
# Error processing date for document '2003.10963.pdf': unconverted data remains: T14:06:27
# Error processing date for document '2003.10965.pdf': unconverted data remains: T00:48:14
# Error processing date for document '2003.13543.pdf': unconverted data remains: T20:24:28
# Error processing date for document '2003.13665.pdf': unconverted data remains: T10:44:53
# Error processing date for document '2004.00579.pdf': unconverted data remains: T20:17:53
# Error processing date for document '2004.01819.pdf': unconverted data remains: T00:20:28
# Error processing date for document '2004.02631.pdf': unconverted data remains: T12:36:11
# Error processing date for document '2004.04470.pdf': unconverted data remains: T20:33:21
# Error processing date for document '2004.07580.pdf': unconverted data remains: T13:22:32
# Error processing date for document '2004.08491.pdf': unconverted data remains: T00:12:43
# Error processing date for document '2004.13689.pdf': unconverted data remains: T01:05:48
# Error processing date for document '2005.01579.pdf': unconverted data remains: T16:41:18
# Error processing date for document '2005.01798.pdf': unconverted data remains: T12:37:17
# Error processing date for document '2005.04055.pdf': unconverted data remains: T10:17:37
# Error processing date for document '2005.04877.pdf': unconverted data remains: T11:08:45
# Error processing date for document '2005.11082.pdf': unconverted data remains: T00:14:38
# Error processing date for document '2005.11767.pdf': unconverted data remains: T20:28:22
# Error processing date for document '2005.12402.pdf': unconverted data remains: T02:01:09
# Error processing date for document '2005.12425.pdf': unconverted data remains: T17:51:45
# Error processing date for document '2006.01511.pdf': unconverted data remains: T12:33:30
# Error processing date for document '2006.03611.pdf': unconverted data remains: T02:48:35
# Error processing date for document '2006.06435.pdf': unconverted data remains: T02:31:28
# Error processing date for document '2006.10884.pdf': unconverted data remains: T00:46:22
# Error processing date for document '2006.13131.pdf': unconverted data remains: T01:16:52
# Error processing date for document '2006.14930.pdf': unconverted data remains: T18:30:49
# Error processing date for document '2007.01363.pdf': unconverted data remains: T02:57:17
# Error processing date for document '2007.03774.pdf': unconverted data remains: T00:49:27
# Error processing date for document '2007.05379.pdf': unconverted data remains: T21:20:03
# Error processing date for document '2007.07429.pdf': unconverted data remains: T02:44:49
# Error processing date for document '2007.08464.pdf': unconverted data remains: T12:11:02
# Error processing date for document '2007.08652.pdf': unconverted data remains: T18:40:40
# Error processing date for document '2007.09093.pdf': unconverted data remains: T18:12:56
# Error processing date for document '2007.10458.pdf': unconverted data remains: T01:09:58
# Error processing date for document '2008.00263.pdf': unconverted data remains: T21:40:17
# Error processing date for document '2008.01126.pdf': unconverted data remains: T01:21:00
# Error processing date for document '2008.01615.pdf': unconverted data remains: T00:52:44
# Error processing date for document '2008.03557.pdf': unconverted data remains: T21:45:37
# Error processing date for document '2008.05377.pdf': unconverted data remains: T15:10:51
# Error processing date for document '2008.08875.pdf': unconverted data remains: T09:48:33
# Error processing date for document '2009.10931.pdf': unconverted data remains: T20:27:54
# Error processing date for document '2009.11549.pdf': unconverted data remains: T10:37:41
# Error processing date for document '2009.12983.pdf': unconverted data remains: T00:06:58
# Error processing date for document '2010.03323.pdf': unconverted data remains: T20:21:18
# Error processing date for document '2010.07473.pdf': unconverted data remains: T01:22:43
# Error processing date for document '2010.11124.pdf': unconverted data remains: T11:19:39
# Error processing date for document '2010.11580.pdf': unconverted data remains: T03:03:48
# Error processing date for document '2010.12902.pdf': unconverted data remains: T00:42:38
# Error processing date for document '2010.12948.pdf': unconverted data remains: T04:54:35
# Error processing date for document '2011.04172.pdf': unconverted data remains: T02:15:07
# Error processing date for document '2011.05342.pdf': unconverted data remains: T16:35:26
# Error processing date for document '2011.05881.pdf': unconverted data remains: T01:51:45
# Error processing date for document '2011.10301.pdf': unconverted data remains: T02:53:31
# Error processing date for document '2011.10372.pdf': unconverted data remains: T21:22:58
# Error processing date for document '2011.10447.pdf': unconverted data remains: T10:19:21
# Error processing date for document '2011.11099.pdf': unconverted data remains: T02:13:27
# Error processing date for document '2011.13012.pdf': unconverted data remains: T20:24:35
# Warning: Missing or invalid date in document '2012.08580.pdf'. Using default old date.
# Error processing date for document '2012.10167.pdf': unconverted data remains: T21:10:41
# Error processing date for document '2012.10338.pdf': unconverted data remains: T02:23:09
# Error processing date for document '2012.12962.pdf': unconverted data remains: T02:00:07
# Error processing date for document '2101.00570.pdf': unconverted data remains: T13:53:25
# Error processing date for document '2101.05746.pdf': unconverted data remains: T10:31:52
# Error processing date for document '2101.06294.pdf': unconverted data remains: T15:22:23
# Error processing date for document '2101.07350.pdf': unconverted data remains: T16:05:22
# Error processing date for document '2102.00836.pdf': unconverted data remains: T02:23:48
# Error processing date for document '2102.02250.pdf': unconverted data remains: T19:29:23
# Error processing date for document '2102.03253.pdf': unconverted data remains: T02:16:22
# Error processing date for document '2102.06526.pdf': unconverted data remains: T15:07:26
# Error processing date for document '2102.13210.pdf': unconverted data remains: T00:16:26
# Error processing date for document '2103.05431.pdf': unconverted data remains: T12:38:46
# Error processing date for document '2103.06145.pdf': unconverted data remains: T17:09:42
# Error processing date for document '2103.10795.pdf': unconverted data remains: T10:23:12
# Error processing date for document '2103.12187.pdf': unconverted data remains: T01:03:37
# Error processing date for document '2103.16587.pdf': unconverted data remains: T12:23:01
# Error processing date for document '2104.01469.pdf': unconverted data remains: T12:27:32
# Error processing date for document '2104.01829.pdf': unconverted data remains: T06:35:36
# Error processing date for document '2104.06109.pdf': unconverted data remains: T15:23:19
# Error processing date for document '2104.10210.pdf': unconverted data remains: T00:45:56
# Error processing date for document '2104.13228.pdf': unconverted data remains: T01:07:08
# Error processing date for document '2105.03410.pdf': unconverted data remains: T01:29:37
# Error processing date for document '2105.06535.pdf': unconverted data remains: T01:38:11
# Error processing date for document '2105.06811.pdf': unconverted data remains: T00:47:10
# Error processing date for document '2106.01756.pdf': unconverted data remains: T12:08:31
# Error processing date for document '2106.02953.pdf': unconverted data remains: T02:38:19
# Error processing date for document '2106.06691.pdf': unconverted data remains: T01:10:42
# Error processing date for document '2106.06929.pdf': unconverted data remains: T01:14:30
# Error processing date for document '2106.07610.pdf': unconverted data remains: T00:33:32
# Error processing date for document '2106.12022.pdf': unconverted data remains: T01:36:10
# Warning: Missing or invalid date in document '2106.13649.pdf'. Using default old date.
# Error processing date for document '2106.14362.pdf': unconverted data remains: T21:32:43
# Error processing date for document '2107.01699.pdf': unconverted data remains: T01:07:35
# Error processing date for document '2107.06823.pdf': unconverted data remains: T18:51:01
# Error processing date for document '2107.07090.pdf': unconverted data remains: T21:05:17
# Error processing date for document '2107.07977.pdf': unconverted data remains: T00:48:38
# Error processing date for document '2107.08575.pdf': unconverted data remains: T03:09:25
# Error processing date for document '2107.12901.pdf': unconverted data remains: T01:11:25
# Error processing date for document '2107.13219.pdf': unconverted data remains: T12:04:28
# Error processing date for document '2108.05186.pdf': unconverted data remains: T22:36:52
# Error processing date for document '2108.08214.pdf': unconverted data remains: T00:42:39
# Error processing date for document '2109.02785.pdf': unconverted data remains: T00:39:27
# Error processing date for document '2109.04038.pdf': unconverted data remains: T01:23:50
# Error processing date for document '2109.04261.pdf': unconverted data remains: T01:46:39
# Error processing date for document '2109.05230.pdf': unconverted data remains: T01:46:05
# Error processing date for document '2109.06123.pdf': unconverted data remains: T02:32:57
# Error processing date for document '2109.09801.pdf': unconverted data remains: T01:03:52
# Warning: Missing or invalid date in document '2110.01731.pdf'. Using default old date.
# Error processing date for document '2110.07605.pdf': unconverted data remains: T15:12:26
# Error processing date for document '2110.11347.pdf': unconverted data remains: T08:12:54
# Error processing date for document '2111.02692.pdf': unconverted data remains: T01:20:39
# Error processing date for document '2111.03565.pdf': unconverted data remains: T11:08:08
# Error processing date for document '2111.04866.pdf': unconverted data remains: T00:45:32
# Error processing date for document '2111.04935.pdf': unconverted data remains: T02:09:29
# Error processing date for document '2111.06247.pdf': unconverted data remains: T01:58:46
# Error processing date for document '2111.06279.pdf': unconverted data remains: T01:39:33
# Error processing date for document '2111.11256.pdf': unconverted data remains: T02:20:08
# Error processing date for document '2111.11753.pdf': unconverted data remains: T02:03:11
# Error processing date for document '2111.13785.pdf': unconverted data remains: T02:38:10
# Error processing date for document '2112.00221.pdf': unconverted data remains: T01:51:41
# Error processing date for document '2112.03259.pdf': unconverted data remains: T23:42:00
# Error processing date for document '2112.07555.pdf': unconverted data remains: T01:55:28
# Error processing date for document '2112.07579.pdf': unconverted data remains: T19:32:05
# Error processing date for document '2112.07760.pdf': unconverted data remains: T01:10:13
# Error processing date for document '2112.08040.pdf': unconverted data remains: T11:57:00
# Error processing date for document '2112.13271.pdf': unconverted data remains: T19:16:16
# Error processing date for document '2112.13273.pdf': unconverted data remains: T20:29:39
# Error processing date for document '2112.14500.pdf': unconverted data remains: T21:00:19
# Error processing date for document '2112.14852.pdf': unconverted data remains: T19:09:33
# Error processing date for document '2201.01818.pdf': unconverted data remains: T10:26:34
# Error processing date for document '2201.04282.pdf': unconverted data remains: T21:03:37
# Error processing date for document '2201.05396.pdf': unconverted data remains: T12:14:53
# Error processing date for document '2201.05612.pdf': unconverted data remains: T17:08:35
# Error processing date for document '2201.06687.pdf': unconverted data remains: T02:22:30
# Error processing date for document '2201.08176.pdf': unconverted data remains: T04:08:58
# Error processing date for document '2201.09854.pdf': unconverted data remains: T18:17:21
# Error processing date for document '2202.00143.pdf': unconverted data remains: T22:52:40
# Error processing date for document '2202.01115.pdf': unconverted data remains: T01:39:47
# Error processing date for document '2202.01672.pdf': unconverted data remains: T01:48:14
# Error processing date for document '2202.05158.pdf': unconverted data remains: T02:03:01
# Error processing date for document '2202.07093.pdf': unconverted data remains: T16:21:56
# Error processing date for document '2202.07171.pdf': unconverted data remains: T03:43:51
# Error processing date for document '2202.09046.pdf': unconverted data remains: T01:39:10
# Error processing date for document '2202.11144.pdf': unconverted data remains: T01:45:56
# Error processing date for document '2203.05488.pdf': unconverted data remains: T01:28:21
# Error processing date for document '2203.12113.pdf': unconverted data remains: T00:51:26
# Error processing date for document '2203.14967.pdf': unconverted data remains: T05:23:17
# Error processing date for document '2204.00007.pdf': unconverted data remains: T10:28:14
# Error processing date for document '2204.03728.pdf': unconverted data remains: T11:29:16
# Error processing date for document '2204.10517.pdf': unconverted data remains: T00:32:02
# Error processing date for document '2204.12440.pdf': unconverted data remains: T00:10:49
# Error processing date for document '2205.03905.pdf': unconverted data remains: T02:38:39
# Error processing date for document '2205.04871.pdf': unconverted data remains: T00:51:14
# Warning: Missing or invalid date in document '2205.08308.pdf'. Using default old date.
# Error processing date for document '2205.10704.pdf': unconverted data remains: T21:14:56
# Error processing date for document '2205.11974.pdf': unconverted data remains: T20:54:09
# Error processing date for document '2206.00293.pdf': unconverted data remains: T00:36:07
# Error processing date for document '2206.08122.pdf': unconverted data remains: T14:45:07
# Error processing date for document '2206.09255.pdf': unconverted data remains: T00:58:18
# Error processing date for document '2208.03139.pdf': unconverted data remains: T13:50:25
# Error processing date for document '2208.05884.pdf': unconverted data remains: T21:33:09
# Warning: Missing or invalid date in document '2208.06382.pdf'. Using default old date.
# Error processing date for document '2208.10465.pdf': unconverted data remains: T02:06:49
# Error processing date for document '2208.11192.pdf': unconverted data remains: T00:13:32
# Error processing date for document '2208.13484.pdf': unconverted data remains: T18:33:59
# Error processing date for document '2209.02592.pdf': unconverted data remains: T01:27:25
# Error processing date for document '2209.13886.pdf': unconverted data remains: T03:19:32
# Error processing date for document '2210.03195.pdf': unconverted data remains: T19:45:07
# Error processing date for document '2210.04479.pdf': unconverted data remains: T00:50:41
# Error processing date for document '2210.05712.pdf': unconverted data remains: T19:18:13
# Error processing date for document '2210.05880.pdf': unconverted data remains: T01:12:42
# Error processing date for document '2210.07309.pdf': unconverted data remains: T00:13:41
# Error processing date for document '2210.13925.pdf': unconverted data remains: T11:41:05
# Error processing date for document '2210.16363.pdf': unconverted data remains: T00:10:59
# Error processing date for document '2211.01867.pdf': unconverted data remains: T00:52:05
# Error processing date for document '2211.02430.pdf': unconverted data remains: T16:15:13
# Error processing date for document '2211.02829.pdf': unconverted data remains: T14:47:27
# Error processing date for document '2211.03507.pdf': unconverted data remains: T16:37:16
# Error processing date for document '2211.04125.pdf': unconverted data remains: T08:31:23
# Warning: Missing or invalid date in document '2211.04817.pdf'. Using default old date.
# Error processing date for document '2211.07024.pdf': unconverted data remains: T06:49:46
# Error processing date for document '2211.07311.pdf': unconverted data remains: T01:50:13
# Error processing date for document '2211.07398.pdf': unconverted data remains: T21:06:19
# Warning: Missing or invalid date in document '2211.08157.pdf'. Using default old date.
# Error processing date for document '2211.08982.pdf': unconverted data remains: T01:29:31
# Error processing date for document '2211.14718.pdf': unconverted data remains: T12:32:12
# Error processing date for document '2212.06114.pdf': unconverted data remains: T01:49:12
# Error processing date for document '2212.06834.pdf': unconverted data remains: T13:45:55
# Error processing date for document '2212.09870.pdf': unconverted data remains: T20:53:08
# Error processing date for document '2212.10362.pdf': unconverted data remains: T00:55:16
# Error processing date for document '2212.10540.pdf': unconverted data remains: T10:00:41
# Error processing date for document '2301.03511.pdf': unconverted data remains: T01:41:18
# Error processing date for document '2301.03964.pdf': unconverted data remains: T01:34:08
# Error processing date for document '2301.05777.pdf': unconverted data remains: T15:55:28
# Error processing date for document '2301.06111.pdf': unconverted data remains: T16:05:37
# Error processing date for document '2301.07459.pdf': unconverted data remains: T19:59:17
# Error processing date for document '2301.08023.pdf': unconverted data remains: T02:41:31
# Error processing date for document '2301.09565.pdf': unconverted data remains: T01:59:35
# Error processing date for document '2301.10397.pdf': unconverted data remains: T00:59:33
# Error processing date for document '2301.11763.pdf': unconverted data remains: T01:33:20
# Error processing date for document '2302.00319.pdf': unconverted data remains: T01:33:29
# Error processing date for document '2302.03211.pdf': unconverted data remains: T09:16:40
# Error processing date for document '2302.05450.pdf': unconverted data remains: T11:42:39
# Error processing date for document '2303.01444.pdf': unconverted data remains: T01:10:42
# Error processing date for document '2303.08042.pdf': unconverted data remains: T00:33:46
# Error processing date for document '2303.10221.pdf': unconverted data remains: T00:55:06
# Error processing date for document '2303.13702.pdf': unconverted data remains: T20:15:09
# Error processing date for document '2304.03131.pdf': unconverted data remains: T17:29:50
# Error processing date for document '2304.05411.pdf': unconverted data remains: T18:20:59
# Error processing date for document '2304.05756.pdf': unconverted data remains: T00:40:02
# Error processing date for document '2304.12963.pdf': unconverted data remains: T00:53:47
# Error processing date for document '2304.14799.pdf': unconverted data remains: T16:39:07
# Error processing date for document '2305.04931.pdf': unconverted data remains: T21:08:40
# Error processing date for document '2305.06808.pdf': unconverted data remains: T01:30:12
# Error processing date for document '2305.11245.pdf': unconverted data remains: T14:06:51
# Error processing date for document '2305.11425.pdf': unconverted data remains: T15:49:58
# Error processing date for document '2306.01689.pdf': unconverted data remains: T08:34:13
# Error processing date for document '2306.05514.pdf': unconverted data remains: T00:26:40
# Error processing date for document '2306.05984.pdf': unconverted data remains: T21:23:01
# Error processing date for document '2306.08096.pdf': unconverted data remains: T01:15:37
# Error processing date for document '2306.09175.pdf': unconverted data remains: T01:46:35
# Error processing date for document '2306.10040.pdf': unconverted data remains: T01:26:42
# Warning: Missing or invalid date in document '2306.10993.pdf'. Using default old date.
# Error processing date for document '2306.12448.pdf': unconverted data remains: T07:10:46
# Error processing date for document '2306.14556.pdf': unconverted data remains: T05:01:31
# Error processing date for document '2306.15811.pdf': unconverted data remains: T01:06:20
# Error processing date for document '2307.01491.pdf': unconverted data remains: T08:44:06
# Error processing date for document '2307.11273.pdf': unconverted data remains: T15:39:56
# Error processing date for document '2307.14372.pdf': unconverted data remains: T14:07:18
# Error processing date for document '2307.15719.pdf': unconverted data remains: T17:00:29
# Error processing date for document '2307.16167.pdf': unconverted data remains: T01:12:25
# Error processing date for document '2307.16231.pdf': unconverted data remains: T15:41:21
# Error processing date for document '2308.01458.pdf': unconverted data remains: T00:47:26
# Error processing date for document '2308.01495.pdf': unconverted data remains: T21:11:40
# Error processing date for document '2308.01830.pdf': unconverted data remains: T02:26:03
# Error processing date for document '2308.08662.pdf': unconverted data remains: T20:20:37
# Error processing date for document '2308.10907.pdf': unconverted data remains: T14:50:55
# Error processing date for document '2308.11671.pdf': unconverted data remains: T01:13:37
# Error processing date for document '2309.00001.pdf': unconverted data remains: T00:43:40
# Error processing date for document '2309.06451.pdf': unconverted data remains: T21:25:07
# Error processing date for document '2309.06886.pdf': unconverted data remains: T11:14:07
# Error processing date for document '2309.07096.pdf': unconverted data remains: T18:41:47
# Error processing date for document '2309.07356.pdf': unconverted data remains: T00:50:00
# Error processing date for document '2309.08064.pdf': unconverted data remains: T06:02:25
# Error processing date for document '2309.10005.pdf': unconverted data remains: T14:06:16
# Error processing date for document '2309.10069.pdf': unconverted data remains: T18:32:27
# Error processing date for document '2309.12055.pdf': unconverted data remains: T03:00:01
# Error processing date for document '2309.14397.pdf': unconverted data remains: T20:50:34
# Error processing date for document '2309.15226.pdf': unconverted data remains: T03:26:16
# Error processing date for document '2309.15838.pdf': unconverted data remains: T00:31:52
# Error processing date for document '2309.15888.pdf': unconverted data remains: T16:03:02
# Error processing date for document '2309.16773.pdf': unconverted data remains: T00:45:04
# Error processing date for document '2309.17106.pdf': unconverted data remains: T01:14:25
# Error processing date for document '2310.01428.pdf': unconverted data remains: T17:34:39
# Error processing date for document '2310.03086.pdf': unconverted data remains: T15:48:38
# Error processing date for document '2310.05822.pdf': unconverted data remains: T02:20:50
# Error processing date for document '2310.07029.pdf': unconverted data remains: T01:15:50
# Error processing date for document '2310.11635.pdf': unconverted data remains: T00:12:13
# Error processing date for document '2310.19950.pdf': unconverted data remains: T19:41:43
# Error processing date for document '2311.00015.pdf': unconverted data remains: T08:57:16
# Error processing date for document '2311.00330.pdf': unconverted data remains: T01:02:01
# Error processing date for document '2311.00392.pdf': unconverted data remains: T09:48:52
# Error processing date for document '2311.01042.pdf': unconverted data remains: T13:49:44
# Error processing date for document '2311.01324.pdf': unconverted data remains: T14:54:32
# Error processing date for document '2311.01543.pdf': unconverted data remains: T18:37:32
# Error processing date for document '2311.03421.pdf': unconverted data remains: T01:31:01
# Warning: Missing or invalid date in document '2311.04425.pdf'. Using default old date.
# Error processing date for document '2311.04468.pdf': unconverted data remains: T15:36:57
# Error processing date for document '2311.04570.pdf': unconverted data remains: T13:07:34
# Error processing date for document '2311.08546.pdf': unconverted data remains: T01:45:09
# Error processing date for document '2311.09561.pdf': unconverted data remains: T23:32:26
# Error processing date for document '2311.09678.pdf': unconverted data remains: T02:24:45
# Error processing date for document '2311.10403.pdf': unconverted data remains: T21:15:06
# Error processing date for document '2311.13342.pdf': unconverted data remains: T12:03:50
# Error processing date for document '2311.13501.pdf': unconverted data remains: T01:07:18
# Error processing date for document '2311.17194.pdf': unconverted data remains: T20:44:41
# Error processing date for document '2312.01788.pdf': unconverted data remains: T04:18:46
# Error processing date for document '2312.02193.pdf': unconverted data remains: T09:42:26
# Error processing date for document '2312.05982.pdf': unconverted data remains: T02:48:11
# Error processing date for document '2312.06215.pdf': unconverted data remains: T10:22:36
# Error processing date for document '2312.13302.pdf': unconverted data remains: T01:52:09
# Error processing date for document '2401.04602.pdf': unconverted data remains: T15:55:29
# Error processing date for document '2401.16052.pdf': unconverted data remains: T03:01:04
# Error processing date for document '2401.16190.pdf': unconverted data remains: T09:02:50
# Error processing date for document '2402.07111.pdf': unconverted data remains: T00:04:59
# Error processing date for document '2402.07497.pdf': unconverted data remains: T15:57:18
# Error processing date for document '2402.07684.pdf': unconverted data remains: T02:29:09
# Error processing date for document '2402.16271.pdf': unconverted data remains: T10:52:16
# Warning: Missing or invalid date in document '2402.17182.pdf'. Using default old date.
# Error processing date for document '2403.04423.pdf': unconverted data remains: T02:28:03
# Error processing date for document '2403.11015.pdf': unconverted data remains: T00:11:21
# Error processing date for document '2403.11753.pdf': unconverted data remains: T12:50:49
# Error processing date for document '2403.14820.pdf': unconverted data remains: T00:15:56
# Error processing date for document '2403.15076.pdf': unconverted data remains: T05:35:47
# Error processing date for document '2403.15926.pdf': unconverted data remains: T03:03:13
# Warning: Missing or invalid date in document '2403.19087.pdf'. Using default old date.
# Error processing date for document '2404.11761.pdf': unconverted data remains: T00:09:08
# Error processing date for document '2404.13265.pdf': unconverted data remains: T12:18:25
# Error processing date for document '2404.13900.pdf': unconverted data remains: T13:41:18
# Error processing date for document '2404.13902.pdf': unconverted data remains: T14:20:41
# Error processing date for document '2404.14353.pdf': unconverted data remains: T16:56:31
# Error processing date for document '2404.15151.pdf': unconverted data remains: T00:55:02
# Error processing date for document '2404.17601.pdf': unconverted data remains: T20:02:16
# Error processing date for document '2404.17952.pdf': unconverted data remains: T00:45:01
# Error processing date for document '2405.07449.pdf': unconverted data remains: T12:57:34
# Error processing date for document '2405.14690.pdf': unconverted data remains: T01:51:16
# Error processing date for document '2405.19057.pdf': unconverted data remains: T00:47:52
# Error processing date for document '2406.01107.pdf': unconverted data remains: T02:02:52
# Error processing date for document '2406.06767.pdf': unconverted data remains: T01:47:55
# Error processing date for document '2406.06969.pdf': unconverted data remains: T01:13:43
# Error processing date for document '2406.13816.pdf': unconverted data remains: T01:00:47
# Error processing date for document '2407.02673.pdf': unconverted data remains: T00:09:18
# Error processing date for document '2407.04799.pdf': unconverted data remains: T15:39:18
# Error processing date for document '2407.05226.pdf': unconverted data remains: T01:16:59
# Error processing date for document '2407.06019.pdf': unconverted data remains: T01:08:58
# Error processing date for document '2407.10215.pdf': unconverted data remains: T00:49:29
# Error processing date for document '2407.10411.pdf': unconverted data remains: T16:52:51
# Error processing date for document '2407.11453.pdf': unconverted data remains: T00:31:02
# Error processing date for document '2407.12060.pdf': unconverted data remains: T23:48:59
# Error processing date for document '2407.12897.pdf': unconverted data remains: T01:09:50
# Error processing date for document '2407.15301.pdf': unconverted data remains: T00:57:11
# Error processing date for document '2407.17601.pdf': unconverted data remains: T13:19:26
# Error processing date for document '2407.21087.pdf': unconverted data remains: T14:53:05
# Error processing date for document '2408.00984.pdf': unconverted data remains: T00:14:30
# Error processing date for document '2408.08832.pdf': unconverted data remains: T00:40:52
# Error processing date for document '2408.09554.pdf': unconverted data remains: T00:46:01
# Error processing date for document '2408.10293.pdf': unconverted data remains: T17:56:29
# Error processing date for document '2408.11884.pdf': unconverted data remains: T01:15:21
# Error processing date for document '2408.14801.pdf': unconverted data remains: T00:23:24
# Error processing date for document '2409.01235.pdf': unconverted data remains: T01:33:43
# Error processing date for document '2409.03353.pdf': unconverted data remains: T00:29:55
# Error processing date for document '2409.05047.pdf': unconverted data remains: T00:42:18
# Error processing date for document '2409.06116.pdf': unconverted data remains: T00:17:17
# Warning: Missing or invalid date in document '2409.06861.pdf'. Using default old date.
# Error processing date for document '2409.08275.pdf': unconverted data remains: T17:51:34
# Error processing date for document '2409.08737.pdf': unconverted data remains: T00:35:17
# Error processing date for document '2409.10714.pdf': unconverted data remains: T00:10:16
# Error processing date for document '2409.16332.pdf': unconverted data remains: T22:45:38
# Error processing date for document '2409.18221.pdf': unconverted data remains: T00:04:19
# Error processing date for document '2409.18879.pdf': unconverted data remains: T01:07:43
# Error processing date for document '2409.20036.pdf': unconverted data remains: T01:18:45
# Error processing date for document '2410.01853.pdf': unconverted data remains: T00:01:24
# Error processing date for document '2410.02085.pdf': unconverted data remains: T00:19:12
# Error processing date for document '2410.04137.pdf': unconverted data remains: T20:13:04
# Error processing date for document '2410.05325.pdf': unconverted data remains: T10:12:44
# Error processing date for document '2410.05923.pdf': unconverted data remains: T00:52:39
# Error processing date for document '2410.07814.pdf': unconverted data remains: T04:18:22
# Error processing date for document '2410.11046.pdf': unconverted data remains: T15:48:29
# Error processing date for document '2410.12830.pdf': unconverted data remains: T01:55:13
# Error processing date for document '2410.15108.pdf': unconverted data remains: T22:48:17
# Error processing date for document '2410.15367.pdf': unconverted data remains: T01:01:41
# Error processing date for document '2410.16169.pdf': unconverted data remains: T02:12:31
# Error processing date for document '2410.18849.pdf': unconverted data remains: T01:07:27
# Error processing date for document '2410.19508.pdf': unconverted data remains: T15:06:50
# Error processing date for document '2410.19667.pdf': unconverted data remains: T20:52:02
# Error processing date for document '2410.20896.pdf': unconverted data remains: T01:19:42
# Error processing date for document '2410.23595.pdf': unconverted data remains: T00:24:05
# Error processing date for document '2411.00063.pdf': unconverted data remains: T16:44:45
# Error processing date for document '2411.00219.pdf': unconverted data remains: T08:06:31
# Error processing date for document '2411.00661.pdf': unconverted data remains: T16:24:12
# Error processing date for document '2411.02354.pdf': unconverted data remains: T03:01:38
# Error processing date for document '2411.02413.pdf': unconverted data remains: T20:01:21
# Error processing date for document '2411.04232.pdf': unconverted data remains: T19:33:51
# Error processing date for document '2411.05017.pdf': unconverted data remains: T01:00:28
# Error processing date for document '2411.05188.pdf': unconverted data remains: T01:07:51
# Error processing date for document '2411.05244.pdf': unconverted data remains: T15:46:04
# Error processing date for document '2411.05795.pdf': unconverted data remains: T01:00:27
# Error processing date for document '2411.10569.pdf': unconverted data remains: T01:06:07
# Error processing date for document '2411.10720.pdf': unconverted data remains: T01:51:33
# Error processing date for document '2411.14130.pdf': unconverted data remains: T10:40:48
# Error processing date for document '2411.19840.pdf': unconverted data remains: T17:42:19
# Error processing date for document '2412.01418.pdf': unconverted data remains: T22:50:39
# Error processing date for document '2412.03614.pdf': unconverted data remains: T01:13:57
# Error processing date for document '2412.06170.pdf': unconverted data remains: T02:12:02
# Error processing date for document '2412.06841.pdf': unconverted data remains: T12:42:03
# Error processing date for document '2412.07136.pdf': unconverted data remains: T20:29:10
# Error processing date for document '2412.09062.pdf': unconverted data remains: T13:47:05
# Error processing date for document '2412.09973.pdf': unconverted data remains: T10:20:15
# Error processing date for document '2412.12815.pdf': unconverted data remains: T01:47:20
# Error processing date for document '2412.14726.pdf': unconverted data remains: T20:43:24
# Error processing date for document '2412.16391.pdf': unconverted data remains: T01:13:06
# Warning: Missing or invalid date in document '2412.18745.pdf'. Using default old date.
# Error processing date for document '2412.19041.pdf': unconverted data remains: T01:37:17
# Error processing date for document '2501.01198.pdf': unconverted data remains: T11:39:26
# Error processing date for document '2501.01510.pdf': unconverted data remains: T01:03:43
# Error processing date for document '2501.02176.pdf': unconverted data remains: T11:32:15
# Error processing date for document '2501.02401.pdf': unconverted data remains: T01:33:27
# Error processing date for document '2501.07043.pdf': unconverted data remains: T02:00:40
# Warning: Missing or invalid date in document '2501.08714.pdf'. Using default old date.
# Error processing date for document '2501.08911.pdf': unconverted data remains: T10:31:54
# Warning: Missing or invalid date in document '2501.09546.pdf'. Using default old date.
# Error processing date for document '2501.11271.pdf': unconverted data remains: T02:05:46
# Error processing date for document '2501.11831.pdf': unconverted data remains: T17:40:43
# Error processing date for document '2501.13657.pdf': unconverted data remains: T01:41:58
# Error processing date for document '2501.15208.pdf': unconverted data remains: T11:57:04
# Warning: Missing or invalid date in document '2501.17158.pdf'. Using default old date.
# Error processing date for document '2503.17418.pdf': unconverted data remains: T11:47:02
# Error processing date for document '2503.16297.pdf': unconverted data remains: T01:04:38
# Error processing date for document '2503.14706.pdf': unconverted data remains: T20:10:49
# Error processing date for document '2503.11282.pdf': unconverted data remains: T00:47:33
# Error processing date for document '2503.12330.pdf': unconverted data remains: T13:26:33
# Error processing date for document '2503.14528.pdf': unconverted data remains: T18:43:01
# Error processing date for document '2503.08378.pdf': unconverted data remains: T12:31:54
# Error processing date for document '2503.07798.pdf': unconverted data remains: T14:20:37
# Error processing date for document '2503.07283.pdf': unconverted data remains: T13:20:57
# Error processing date for document '2503.06797.pdf': unconverted data remains: T22:25:19
# Error processing date for document '2503.06123.pdf': unconverted data remains: T16:17:35
# Error processing date for document '2503.04069.pdf': unconverted data remains: T12:03:56
# Error processing date for document '2503.02569.pdf': unconverted data remains: T13:45:29
# Error processing date for document '2503.00197.pdf': unconverted data remains: T01:10:24
# Error processing date for document '2502.19748.pdf': unconverted data remains: T01:24:19
# Error processing date for document '2502.19292.pdf': unconverted data remains: T05:41:48
# Error processing date for document '2502.18864.pdf': unconverted data remains: T01:27:12
# Error processing date for document '2502.16557.pdf': unconverted data remains: T02:02:05
# Error processing date for document '2502.12279.pdf': unconverted data remains: T01:04:23
# Error processing date for document '2502.12186.pdf': unconverted data remains: T01:00:55
# Error processing date for document '2502.10067.pdf': unconverted data remains: T01:40:14
# Error processing date for document '2502.06883.pdf': unconverted data remains: T01:02:55
# Error processing date for document '2502.08070.pdf': unconverted data remains: T21:16:27
# Error processing date for document '2502.07836.pdf': unconverted data remains: T01:30:03
# Error processing date for document '2502.05039.pdf': unconverted data remains: T01:53:45
# Error processing date for document '2502.03499.pdf': unconverted data remains: T01:21:45
# Error processing date for document '2501.19030.pdf': unconverted data remains: T01:30:16
# Error processing date for document '2502.00979.pdf': unconverted data remains: T01:17:44
# Error processing date for document '2501.19343.pdf': unconverted data remains: T21:11:26
# Error processing date for document '2501.17838.pdf': unconverted data remains: T18:13:41

# %%
# Sort by the most recent based on the date or filename
#relevant_documents.sort(key=lambda x: x["date"], reverse=True)  # Sort by 'date' or 'filename'

# %%
# Select the 15 most recent relevant documents
top_15_documents = relevant_documents[:15]

# %%
summaries = []
for document in top_15_documents:
    try:
        # Ensure document is a dictionary
        if not isinstance(document, dict):
            print(f"Warning: Skipping invalid document entry: {document}")
            continue

        # Check if "processed_text" exists and is valid
        processed_text = document.get("processed_text", "").strip()
        if not processed_text:
            print(f"Warning: Missing or empty processed text for '{document.get('filename', 'Unknown')}'. Using default summary.")
            summary = "No summary available due to missing or empty content."
        else:
            summary = summarize_document(processed_text)

        summaries.append({
            'title': document.get("title", "Unknown Title"),
            'author': document.get("author", "Unknown Author"),
            'date': document.get("date", "Unknown Date"),
            'filename': document.get("filename", "Unknown Filename"),
            'summary': summary
        })
    
    except Exception as e:
        print(f"Error summarizing document '{document.get('filename', 'Unknown')}': {e}")
        summaries.append({
            'title': document.get("title", "Unknown Title"),
            'author': document.get("author", "Unknown Author"),
            'date': document.get("date", "Unknown Date"),
            'filename': document.get("filename", "Unknown Filename"),
            'summary': "Error generating summary."
        })
# Out:
# Error summarizing document '0706.1996.pdf': index out of range in self
# Error summarizing document '1102.0933.pdf': index out of range in self
# Error summarizing document '1102.3369.pdf': index out of range in self
# Error summarizing document '1109.1296.pdf': index out of range in self
# Error summarizing document '1201.2900.pdf': index out of range in self
# Error summarizing document '1207.1891.pdf': index out of range in self
# Error summarizing document '1209.5046.pdf': index out of range in self
# Error summarizing document '1209.5754.pdf': index out of range in self
# Error summarizing document '1210.0037.pdf': index out of range in self
# Error summarizing document '1210.7480.pdf': index out of range in self
# Error summarizing document '1211.4911.pdf': index out of range in self
# Error summarizing document '1301.1077.pdf': index out of range in self
# Error summarizing document '1302.3861.pdf': index out of range in self
# Error summarizing document '1304.0479.pdf': index out of range in self
# Error summarizing document '1304.3546.pdf': index out of range in self

# %%
# Display the summaries of the top 15 relevant documents
for summary in summaries:
    print(f"Document: {summary['title']} ({summary['filename']})")
    print(f"Author: {summary['author']}")
    print(f"Date: {summary['date']}")
    print(f"Summary: {summary['summary']}")
    print("="*50)
# Out:
# Document: RTR Planet RB4arXiv June 2007 (0706.1996.pdf)
# Author: Razvan T. Radulescu
# Date: 2007-06-13T23:21:48
# Summary: Error generating summary.
# ==================================================
# Document: Unknown Title (1102.0933.pdf)
# Author: Unknown Author
# Date: 2018-10-22T13:41:06
# Summary: Error generating summary.
# ==================================================
# Document: Microsoft Word - Gen_med_insilmac_acc_chng.doc (1102.3369.pdf)
# Author: Steven Watterson
# Date: 2011-01-28T11:49:30
# Summary: Error generating summary.
# ==================================================
# Document: Unknown Title (1109.1296.pdf)
# Author: Unknown Author
# Date: 2022-03-28T02:25:30
# Summary: Error generating summary.
# ==================================================
# Document: Model of pathogenesis of psoriasis. Part 2. Local processes. (1201.2900.pdf)
# Author: Mikhail Peslyak
# Date: None
# Summary: Error generating summary.
# ==================================================
# Document: Unknown Title (1207.1891.pdf)
# Author: sachin
# Date: 2012-07-08T22:37:20
# Summary: Error generating summary.
# ==================================================
# Document: Unknown Title (1209.5046.pdf)
# Author: Unknown Author
# Date: 2022-03-12T07:18:13
# Summary: Error generating summary.
# ==================================================
# Document: View 10 Articles from Experimental Cell Research for style (1209.5754.pdf)
# Author: Paul Heroux
# Date: 2012-09-17T11:42:42
# Summary: Error generating summary.
# ==================================================
# Document: Template for Electronic Submission to ACS Journals (1210.0037.pdf)
# Author: User
# Date: 2012-09-27T16:35:17
# Summary: Error generating summary.
# ==================================================
# Document: Unknown Title (1210.7480.pdf)
# Author: Unknown Author
# Date: 2019-05-09T01:01:44
# Summary: Error generating summary.
# ==================================================
# Document: Unknown Title (1211.4911.pdf)
# Author: Unknown Author
# Date: 2018-09-03T22:18:10
# Summary: Error generating summary.
# ==================================================
# Document: Unknown Title (1301.1077.pdf)
# Author: Unknown Author
# Date: 2013-01-07T01:36:25
# Summary: Error generating summary.
# ==================================================
# Document: Unknown Title (1302.3861.pdf)
# Author: Matt
# Date: 2011-09-12T06:59:03
# Summary: Error generating summary.
# ==================================================
# Document: Microsoft Word - Arxiv_v2.docx (1304.0479.pdf)
# Author: Wendy Ingram
# Date: 2013-07-11T20:21:45
# Summary: Error generating summary.
# ==================================================
# Document: Unknown Title (1304.3546.pdf)
# Author: AB
# Date: 2013-04-12T08:36:57
# Summary: Error generating summary.
# ==================================================

# %%
# Overall summary of the top 15 documents
combined_text = " ".join([doc["processed_text"] for doc in top_15_documents])
overall_summary = summarize_document(combined_text)
print("Overall Summary of the Top 15 Documents:")
print(overall_summary)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[37], line 3
#       1 # Overall summary of the top 15 documents
#       2 combined_text = " ".join([doc["processed_text"] for doc in top_15_documents])
# ----> 3 overall_summary = summarize_document(combined_text)
#       4 print("Overall Summary of the Top 15 Documents:")
#       5 print(overall_summary)
#
# Cell In[19], line 5, in summarize_document(text)
#       4 def summarize_document(text):
# ----> 5     summary = summarizer(text, max_length=200, min_length=50, do_sample=False)
#       6     return summary[0]['summary_text']
#
# File c:\Users\email\Desktop\DS_Science_Youth_Extension\2504_Science_Youth\.venv\Lib\site-packages\transformers\pipelines\text2text_generation.py:280, in SummarizationPipeline.__call__(self, *args, **kwargs)
#     256 def __call__(self, *args, **kwargs):
#     257     r"""
#     258     Summarize the text(s) given as inputs.
#     259
#    (...)    278           ids of the summary.
#     279     """
# --> 280     return super().__call__(*args, **kwargs)
#
# File c:\Users\email\Desktop\DS_Science_Youth_Extension\2504_Science_Youth\.venv\Lib\site-packages\transformers\pipelines\text2text_generation.py:173, in Text2TextGenerationPipeline.__call__(self, *args, **kwargs)
#     144 def __call__(self, *args, **kwargs):
#     145     r"""
#     146     Generate the output text(s) using text(s) given as inputs.
#     147
#    (...)    170           ids of the generated text.
#     171     """
# --> 173     result = super().__call__(*args, **kwargs)
#     174     if (
#     175         isinstance(args[0], list)
#     176         and all(isinstance(el, str) for el in args[0])
#     177         and all(len(res) == 1 for res in result)
#     178     ):
#     179         return [res[0] for res in result]
#
# File c:\Users\email\Desktop\DS_Science_Youth_Extension\2504_Science_Youth\.venv\Lib\site-packages\transformers\pipelines\base.py:1371, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1363     return next(
#    1364         iter(
#    1365             self.get_iterator(
#    (...)   1368         )
#    1369     )
#    1370 else:
# -> 1371     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File c:\Users\email\Desktop\DS_Science_Youth_Extension\2504_Science_Youth\.venv\Lib\site-packages\transformers\pipelines\base.py:1378, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1376 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1377     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1378     model_outputs = self.forward(model_inputs, **forward_params)
#    1379     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1380     return outputs
#
# File c:\Users\email\Desktop\DS_Science_Youth_Extension\2504_Science_Youth\.venv\Lib\site-packages\transformers\pipelines\base.py:1278, in Pipeline.forward(self, model_inputs, **forward_params)
#    1276     with inference_context():
#    1277         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1278         model_outputs = self._forward(model_inputs, **forward_params)
#    1279         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1280 else:
#
# File c:\Users\email\Desktop\DS_Science_Youth_Extension\2504_Science_Youth\.venv\Lib\site-packages\transformers\pipelines\text2text_generation.py:202, in Text2TextGenerationPipeline._forward(self, model_inputs, **generate_kwargs)
#     199 if "generation_config" not in generate_kwargs:
#     200     generate_kwargs["generation_config"] = self.generation_config
# --> 202 output_ids = self.model.generate(**model_inputs, **generate_kwargs)
#     203 out_b = output_ids.shape[0]
#     204 if self.framework == "pt":
#
# File c:\Users\email\Desktop\DS_Science_Youth_Extension\2504_Science_Youth\.venv\Lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File c:\Users\email\Desktop\DS_Science_Youth_Extension\2504_Science_Youth\.venv\Lib\site-packages\transformers\generation\utils.py:2141, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, **kwargs)
#    2137         raise ValueError("`attention_mask` passed to `generate` must be 2D.")
#    2139 if self.config.is_encoder_decoder and "encoder_outputs" not in model_kwargs:
#    2140     # if model is encoder decoder encoder_outputs are created and added to `model_kwargs`
# -> 2141     model_kwargs = self._prepare_encoder_decoder_kwargs_for_generation(
#    2142         inputs_tensor, model_kwargs, model_input_name, generation_config
#    2143     )
#    2145 # 5. Prepare `input_ids` which will be used for auto-regressive generation
#    2146 if self.config.is_encoder_decoder:
#
# File c:\Users\email\Desktop\DS_Science_Youth_Extension\2504_Science_Youth\.venv\Lib\site-packages\transformers\generation\utils.py:692, in GenerationMixin._prepare_encoder_decoder_kwargs_for_generation(self, inputs_tensor, model_kwargs, model_input_name, generation_config)
#     690 encoder_kwargs["return_dict"] = True
#     691 encoder_kwargs[model_input_name] = inputs_tensor
# --> 692 model_kwargs["encoder_outputs"]: ModelOutput = encoder(**encoder_kwargs)  # type: ignore
#     694 return model_kwargs
#
# File c:\Users\email\Desktop\DS_Science_Youth_Extension\2504_Science_Youth\.venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\email\Desktop\DS_Science_Youth_Extension\2504_Science_Youth\.venv\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Users\email\Desktop\DS_Science_Youth_Extension\2504_Science_Youth\.venv\Lib\site-packages\transformers\models\bart\modeling_bart.py:1061, in BartEncoder.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#    1058 if inputs_embeds is None:
#    1059     inputs_embeds = self.embed_tokens(input_ids)
# -> 1061 embed_pos = self.embed_positions(input)
#    1062 embed_pos = embed_pos.to(inputs_embeds.device)
#    1064 hidden_states = inputs_embeds + embed_pos
#
# File c:\Users\email\Desktop\DS_Science_Youth_Extension\2504_Science_Youth\.venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\email\Desktop\DS_Science_Youth_Extension\2504_Science_Youth\.venv\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Users\email\Desktop\DS_Science_Youth_Extension\2504_Science_Youth\.venv\Lib\site-packages\transformers\models\bart\modeling_bart.py:116, in BartLearnedPositionalEmbedding.forward(self, input_ids, past_key_values_length)
#     111 bsz, seq_len = input_ids.shape[:2]
#     112 positions = torch.arange(
#     113     past_key_values_length, past_key_values_length + seq_len, dtype=torch.long, device=self.weight.device
#     114 ).expand(bsz, -1)
# --> 116 return super().forward(positions + self.offset)
#
# File c:\Users\email\Desktop\DS_Science_Youth_Extension\2504_Science_Youth\.venv\Lib\site-packages\torch\nn\modules\sparse.py:190, in Embedding.forward(self, input)
#     189 def forward(self, input: Tensor) -> Tensor:
# --> 190     return F.embedding(
#     191         input,
#     192         self.weight,
#     193         self.padding_idx,
#     194         self.max_norm,
#     195         self.norm_type,
#     196         self.scale_grad_by_freq,
#     197         self.sparse,
#     198     )
#
# File c:\Users\email\Desktop\DS_Science_Youth_Extension\2504_Science_Youth\.venv\Lib\site-packages\torch\nn\functional.py:2551, in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2545     # Note [embedding_renorm set_grad_enabled]
#    2546     # XXX: equivalent to
#    2547     # with torch.no_grad():
#    2548     #   torch.embedding_renorm_
#    2549     # remove once script supports set_grad_enabled
#    2550     _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2551 return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#
# IndexError: index out of range in self

# %% [markdown]
# Deployment Options: Depending on your application, you can deploy the model as a REST API using frameworks like Flask or FastAPI, integrate it into existing data pipelines, or utilize it within interactive applications.​
